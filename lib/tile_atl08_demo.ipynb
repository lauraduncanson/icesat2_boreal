# %% [markdown]
# # Demo of the `tile_atl08` procedure for version 1 of Boreal mapping
# Paul Montesano, PhD
#
# This performs spatial and quality filters of ATL08 30m granules based on tile extents and our quality flags and thresholds

# %%
from maap.maap import MAAP
maap = MAAP()

# %%
ICESAT2_BOREAL_REPO_PATH = '/projects/code/icesat2_boreal'               #'/projects/icesat2_boreal' # /projects/Developer/icesat2_boreal/lib
ICESAT2_BOREAL_LIB_PATH = ICESAT2_BOREAL_REPO_PATH + '/lib'

# %%
import geopandas
import pandas as pd
import os
import json
import collections
import numpy as np
import sys
import s3fs
import matplotlib.pyplot as plt
sys.path.append(ICESAT2_BOREAL_LIB_PATH)
import maplib_folium
from mosaiclib import *
#import ExtractUtils
from folium import TileLayer
print("Importing packages complete.")
# Out:
# Importing packages complete.

# %%
HLS_TINDEX_FN_DICT
# Out:
# {'c2020oldv1': 's3://maap-ops-workspace/shared/nathanmthomas/DPS_tile_lists/HLS/spring2022/HLS_tindex_master.csv',
#  'c2020oldv2': 's3://maap-ops-workspace/shared/nathanmthomas/DPS_tile_lists/HLS/fall2022/HLS_stack_2022_v2/HLS_tindex_master.csv',
#  'c2020v2022': 's3://maap-ops-workspace/shared/nathanmthomas/DPS_tile_lists/HLS/c2020/HLS_stack_2022_v2/HLS_tindex_master.csv',
#  'c2020v2022datelines': 's3://maap-ops-workspace/shared/montesano/DPS_tile_lists/HLS/HLS_stack_2023_v1/HLS_L30_c2020/HLS_tindex_master.csv',
#  'c2020updated': 's3://maap-ops-workspace/shared/montesano/DPS_tile_lists/HLS/HLS_stack_2022_v2/HLS_tindex_master.csv',
#  '2015': 's3://maap-ops-workspace/shared/nathanmthomas/DPS_tile_lists/HLS/c2015/HLS_stack_2022_v2/11/HLS_tindex_master.csv',
#  '2016': 's3://maap-ops-workspace/shared/montesano/DPS_tile_lists/HLS/HLS_stack_2023_v1/HLS_H30_2016/HLS_tindex_master.csv',
#  '2017': 's3://maap-ops-workspace/shared/montesano/DPS_tile_lists/HLS/HLS_stack_2023_v1/HLS_H30_2017/HLS_tindex_master.csv',
#  '2018': 's3://maap-ops-workspace/shared/montesano/DPS_tile_lists/HLS/HLS_stack_2023_v1/HLS_H30_2018/HLS_tindex_master.csv',
#  '2019': 's3://maap-ops-workspace/shared/montesano/DPS_tile_lists/HLS/HLS_stack_2023_v1/HLS_H30_2019/HLS_tindex_master.csv',
#  '2020': 's3://maap-ops-workspace/shared/montesano/DPS_tile_lists/HLS/HLS_stack_2023_v1/HLS_H30_2020/HLS_tindex_master.csv',
#  '2021': 's3://maap-ops-workspace/shared/montesano/DPS_tile_lists/HLS/HLS_stack_2023_v1/HLS_H30_2021/HLS_tindex_master.csv',
#  '2022': 's3://maap-ops-workspace/shared/montesano/DPS_tile_lists/HLS/HLS_stack_2023_v1/HLS_H30_2022/HLS_tindex_master.csv',
#  '2023': 's3://maap-ops-workspace/shared/montesano/DPS_tile_lists/HLS/HLS_stack_2023_v1/HLS_H30_2023/HLS_tindex_master.csv'}

# %%
TILE_NUM= 4180700 
#
# 
#

fn_datelines = HLS_TINDEX_FN_DICT['c2020v2022datelines']
fn = HLS_TINDEX_FN_DICT['c2020updated']
#fn = '/projects/shared-buckets/nathanmthomas/DPS_tile_lists/HLS/c2020/HLS_stack_2022_v2/HLS_tindex_master.csv'
#fn = '/projects/shared-buckets/nathanmthomas/DPS_tile_lists/HLS/c2020/HLS_stack_2023_v1/HLS_tindex_master.csv'
z = pd.concat([pd.read_csv( fn_datelines), pd.read_csv( fn) ] )
print(z.shape)
z[z.tile_num==TILE_NUM]
# Out:
# (5273, 6)
#     index                                            s3_path  \
# 13     13  s3://maap-ops-workspace/montesano/dps_output/d...
#
#                                            local_path  \
# 13  /projects/my-private-bucket/dps_output/do_HLS_...
#
#                                      file  tile_num        creation time
# 13  HLS_4180700_07-01_08-31_2019_2021.tif   4180700  2024-02-05 13:50:28

# %%
OUTDIR = '/projects/my-public-bucket/local_output/tile_atl08_demo'

# %%
in_tile_fn = '/projects/shared-buckets/montesano/databank/boreal_tiles_v004.gpkg'
in_tile_layer = 'boreal_tiles_v004'
in_tile_id_col = 'tile_num'
csv_list_fn = '/projects/shared-buckets/lduncanson/DPS_tile_lists/ATL08_tindex_master.csv'
landsat_stack_list_fn = HLS_TINDEX_FN_DICT['c2020v2022datelines'] # /projects/shared-buckets/nathanmthomas/DPS_tile_lists/HLS_tindex_master.csv
#landsat_stack_list_fn = 'projects/shared-buckets/nathanmthomas/DPS_tile_lists/HLS/c2020/HLS_stack_2022_v2/HLS_tindex_master.csv'
topo_stack_list_fn    = 's3://maap-ops-workspace/shared/montesano/DPS_tile_lists/run_build_stack_topo/build_stack_v2023_2/CopernicusGLO30/Topo_tindex_master.csv'
sar_stack_list_fn     = 's3://maap-ops-workspace/shared/montesano/DPS_tile_lists/run_build_stack/build_stack_v2023_2/build_stack_S1/SAR_S1_2020/S1_tindex_master.csv'
MINMONTH = 4
MAXMONTH = 10

# %%
args = f"\
--extract_covars \
--do_30m \
--do_dps \
-years_list 2019 2020 2021 \
-o {OUTDIR} \
-in_tile_num {TILE_NUM} \
-in_tile_fn {in_tile_fn} \
-in_tile_layer {in_tile_layer} \
-in_tile_id_col {in_tile_id_col} \
-csv_list_fn {csv_list_fn} \
-topo_stack_list_fn {topo_stack_list_fn} \
-landsat_stack_list_fn {landsat_stack_list_fn} \
-landsat_cols_list Blue Green Red NIR SWIR SWIR2 NDVI SAVI MSAVI NDMI EVI NBR NBR2 TCB TCG TCW ValidMask Xgeo Ygeo JulianDate yearDate \
-user_atl08 lduncanson \
-thresh_sol_el 5 \
-v_ATL08 5 \
-minmonth {MINMONTH} \
-maxmonth {MAXMONTH} \
-LC_filter True"

#print(args)
# !time python tile_atl08.py $args
# Out:
# NASA MAAP
#
# Land cover filtering set to: True
#
# Working on tile:	 4180700
# From layer:		 boreal_tiles_v004
# In vector file:		 /projects/shared-buckets/montesano/databank/boreal_tiles_v004.gpkg
# ATL08 version:		 5
# Season start:		 04-01
# Season end:		 10-31
# Years:			 [2019, 2020, 2021]
# ATL08 bin length:	 30m
#
# Doing MAAP query by tile bounds to find all intersecting ATL08
# 	TILE_NUM: 4180700 (-179.99999,68.00324362250025,-179.78787952810754,68.80542153243888)
# 	Searching MAAP for granules using these parameters:
# 	[{'short_name': 'ATL08', 'version': '006', 'bounding_box': '-179.99999,68.00324362250025,-179.78787952810754,68.80542153243888', 'limit': 10000, 'temporal': '2019-04-01T00:00:00Z,2019-10-31T23:59:59Z'}, {'short_name': 'ATL08', 'version': '006', 'bounding_box': '-179.99999,68.00324362250025,-179.78787952810754,68.80542153243888', 'limit': 10000, 'temporal': '2020-04-01T00:00:00Z,2020-10-31T23:59:59Z'}, {'short_name': 'ATL08', 'version': '006', 'bounding_box': '-179.99999,68.00324362250025,-179.78787952810754,68.80542153243888', 'limit': 10000, 'temporal': '2021-04-01T00:00:00Z,2021-10-31T23:59:59Z'}]
# 		# ATL08 for tile 4180700: 70
#
# This is either a DPS job (for which the CSV has an s3 path) or the CSV exists locally.
#
# Reading existing list of ATL08 CSVs: /projects/shared-buckets/lduncanson/DPS_tile_lists/ATL08_tindex_master.csv
# 	Doing 30m ATL08 data?  True
# 	Find ATL08 CSVs you expect for a tile based on the h5 granule search...
# 		# of all ATL08 granules for tile: 70
# 		# of all_atl08_csvs: 46166
# 	# of ATL08 CSV found for tile 4180700: 26
# 	# of ATL08 CSV NOT found for tile 4180700: 44
# Creating pandas data frame...
#
# Filtering by tile: 4180700
# [-179.99999, -179.78787952810754, 68.00324362250025, 68.80542153243888]
# is df
# Bounds clipped 34256 obs. down to 0 obs.
# is df
# Bounds clipped 25066 obs. down to 403 obs.
# is df
# Bounds clipped 80669 obs. down to 1401 obs.
# is df
# Bounds clipped 73428 obs. down to 6192 obs.
# is df
# Bounds clipped 69802 obs. down to 4916 obs.
# is df
# Bounds clipped 55538 obs. down to 1010 obs.
# is df
# Bounds clipped 18233 obs. down to 0 obs.
# is df
# Bounds clipped 80693 obs. down to 1064 obs.
# is df
# Bounds clipped 34256 obs. down to 0 obs.
# is df
# Bounds clipped 25066 obs. down to 403 obs.
# is df
# Bounds clipped 80669 obs. down to 1401 obs.
# is df
# Bounds clipped 73428 obs. down to 6192 obs.
# is df
# Bounds clipped 69802 obs. down to 4916 obs.
# is df
# Bounds clipped 55538 obs. down to 1010 obs.
# is df
# Bounds clipped 18233 obs. down to 0 obs.
# is df
# Bounds clipped 80693 obs. down to 1064 obs.
# is df
# Bounds clipped 31824 obs. down to 0 obs.
# is df
# Bounds clipped 32682 obs. down to 438 obs.
# is df
# Bounds clipped 25584 obs. down to 27 obs.
# is df
# Bounds clipped 71461 obs. down to 6817 obs.
# is df
# Bounds clipped 42422 obs. down to 1359 obs.
# is df
# Bounds clipped 31824 obs. down to 0 obs.
# is df
# Bounds clipped 32682 obs. down to 438 obs.
# is df
# Bounds clipped 25584 obs. down to 27 obs.
# is df
# Bounds clipped 71461 obs. down to 6817 obs.
# is df
# Bounds clipped 42422 obs. down to 1359 obs.
#
# Pre-filter data cleaning...
# Pandas version: 2.1.4
# 	Get beam type from orbit orientation and ground track: ['Strong' 'Weak']
# 	Cast some columns to:
# 		type float: ['lat', 'lon', 'h_can', 'h_te_best', 'ter_slp']
# 		type integer: ['n_ca_ph', 'n_seg_ph', 'n_toc_ph', 'msw_flg', 'seg_snow']
# Quality filtering with aggressive land-cover based (v3) filters updated in Jan/Feb 2022 ...
#
# Filtering by quality
# 	Before quality filtering: 		47254 observations in the input dataframe.
# 	After msw_flg=0: 		33400 observations in the dataframe.
# 	After beam_type=Strong: 		17810 observations in the dataframe.
# 	After seg_snow=1: 		16012 observations in the dataframe.
# 	Land cover threshold dictionary:
# {0: 0, 111: 60, 113: 60, 112: 60, 114: 60, 115: 60, 116: 60, 121: 50, 123: 50, 122: 50, 124: 50, 125: 50, 126: 50, 20: 20, 30: 10, 90: 10, 100: 5, 60: 5, 40: 0, 50: 0, 70: 0, 80: 0, 200: 0}
# 	After land-cover specific h_can thresholds: 		4362 observations in the dataframe.
# 	After h_can_unc <5, seg_cover<32767, sol_el<5, sig_topo<2.5, h_dif_ref<25: 		698 observations in the dataframe.
# 	After month filters: 4-10
# 	After all quality filtering: 		698 observations in the output dataframe.
# 	Returning a pandas data frame.
# 	Filtered obs. for columns: ['lon', 'lat', 'rh25', 'rh50', 'rh60', 'rh70', 'rh75', 'rh80', 'rh90', 'h_can', 'h_max_can', 'ter_slp', 'h_te_best', 'seg_landcov', 'sol_el', 'y', 'm', 'doy', 'seg_cover']
# 	Data frame shape: (698, 19)
#
# Converting to geopandas data frame in lat/lon ...
#
# Getting stack fn from:  s3://maap-ops-workspace/shared/montesano/DPS_tile_lists/run_build_stack_topo/build_stack_v2023_2/CopernicusGLO30/Topo_tindex_master.csv
# 	 s3://maap-ops-workspace/montesano/dps_output/run_build_stack_topo/build_stack_v2023_2/CopernicusGLO30/2024/01/13/13/02/18/401227/CopernicusGLO30_4180700_cog_topo_stack.tif
#
# Getting stack fn from:  s3://maap-ops-workspace/shared/montesano/DPS_tile_lists/HLS/HLS_stack_2023_v1/HLS_L30_c2020/HLS_tindex_master.csv
# 	 s3://maap-ops-workspace/montesano/dps_output/do_HLS_stack_3-1-2/HLS_stack_2023_v1/HLS_L30_c2020/mc25_07-01_08-31_2019_2021/2024/02/05/21/50/20/986446/HLS_4180700_07-01_08-31_2019_2021.tif
#
# Extract covars for 698 ATL08 obs...
# 	Extracting raster values from:  s3://maap-ops-workspace/montesano/dps_output/run_build_stack_topo/build_stack_v2023_2/CopernicusGLO30/2024/01/13/13/02/18/401227/CopernicusGLO30_4180700_cog_topo_stack.tif
# 	Re-project points to match raster...
# 	Returning 698 points with 5 new raster value columns: ['elevation', 'slope', 'tsri', 'tpi', 'slopemask']
# 	Extracting raster values from:  s3://maap-ops-workspace/montesano/dps_output/do_HLS_stack_3-1-2/HLS_stack_2023_v1/HLS_L30_c2020/mc25_07-01_08-31_2019_2021/2024/02/05/21/50/20/986446/HLS_4180700_07-01_08-31_2019_2021.tif
# 	Returning 698 points with 21 new raster value columns: ['Blue', 'Green', 'Red', 'NIR', 'SWIR', 'SWIR2', 'NDVI', 'SAVI', 'MSAVI', 'NDMI', 'EVI', 'NBR', 'NBR2', 'TCB', 'TCG', 'TCW', 'ValidMask', 'Xgeo', 'Ygeo', 'JulianDate', 'yearDate']
# Writing a the tile's CSV with extracted covars:
# /projects/my-public-bucket/local_output/tile_atl08_demo/atl08_005_30m_filt_topo_landsat_20240217_4180700.csv
# Writing a sample CSV of 250 sol elev obs. < 5: /projects/my-public-bucket/local_output/tile_atl08_demo/atl08_005_30m_filt_topo_landsat_20240217_4180700_SAMPLE_n250.csv
# Wrote output csv/geojson of filtered ATL08 obs with topo and Landsat covariates for tile 4180700: /projects/my-public-bucket/local_output/tile_atl08_demo/atl08_005_30m_filt_topo_landsat_20240217_4180700
#
# real	1m7.479s
# user	0m22.740s
# sys	0m3.846s

# %% [markdown]
# # Results from `tile_atl08`: Map the filtered ATL08 for this tile

# %%
boreal_tiles = geopandas.read_file('/projects/shared-buckets/montesano/databank/boreal_tiles_v004.gpkg')

# %%
atl08_pdf_filt = pd.read_csv(os.path.join(OUTDIR, 'atl08_005_30m_filt_topo_landsat_20240217_3540.csv'))
print("\nConverting to geopandas data frame in lat/lon ...")
atl08_gdf = geopandas.GeoDataFrame(atl08_pdf_filt, geometry=geopandas.points_from_xy(atl08_pdf_filt.lon, atl08_pdf_filt.lat), crs='epsg:4326')
# Out:
# Converting to geopandas data frame in lat/lon ...

# %%
atl08_gdf.shape
# Out:
# (1566, 46)

# %%
import maplib_folium
import branca.colormap as cm
pal_height_cmap = cm.LinearColormap(colors = ['black','#636363','#fc8d59','#fee08b','#ffffbf','#d9ef8b','#91cf60','#1a9850'], vmin=0, vmax=25)
pal_height_cmap.caption = 'Vegetation height from  ATL08 @ 30 m (h_can; rh98)'
pal_height_cmap
# Out:
# <svg height="40" width="450"><line x1="0" y1="15" x2="0" y2="27" style="stroke:#000000ff;stroke-width:2;" /><line x1="1" y1="15" x2="1" y2="27" style="stroke:#010101ff;stroke-width:2;" /><line x1="2" y1="15" x2="2" y2="27" style="stroke:#030303ff;stroke-width:2;" /><line x1="3" y1="15" x2="3" y2="27" style="stroke:#040404ff;stroke-width:2;" /><line x1="4" y1="15" x2="4" y2="27" style="stroke:#060606ff;stroke-width:2;" /><line x1="5" y1="15" x2="5" y2="27" style="stroke:#070707ff;stroke-width:2;" /><line x1="6" y1="15" x2="6" y2="27" style="stroke:#090909ff;stroke-width:2;" /><line x1="7" y1="15" x2="7" y2="27" style="stroke:#0a0a0aff;stroke-width:2;" /><line x1="8" y1="15" x2="8" y2="27" style="stroke:#0c0c0cff;stroke-width:2;" /><line x1="9" y1="15" x2="9" y2="27" style="stroke:#0d0d0dff;stroke-width:2;" /><line x1="10" y1="15" x2="10" y2="27" style="stroke:#0f0f0fff;stroke-width:2;" /><line x1="11" y1="15" x2="11" y2="27" style="stroke:#111111ff;stroke-width:2;" /><line x1="12" y1="15" x2="12" y2="27" style="stroke:#121212ff;stroke-width:2;" /><line x1="13" y1="15" x2="13" y2="27" style="stroke:#141414ff;stroke-width:2;" /><line x1="14" y1="15" x2="14" y2="27" style="stroke:#151515ff;stroke-width:2;" /><line x1="15" y1="15" x2="15" y2="27" style="stroke:#171717ff;stroke-width:2;" /><line x1="16" y1="15" x2="16" y2="27" style="stroke:#181818ff;stroke-width:2;" /><line x1="17" y1="15" x2="17" y2="27" style="stroke:#1a1a1aff;stroke-width:2;" /><line x1="18" y1="15" x2="18" y2="27" style="stroke:#1b1b1bff;stroke-width:2;" /><line x1="19" y1="15" x2="19" y2="27" style="stroke:#1d1d1dff;stroke-width:2;" /><line x1="20" y1="15" x2="20" y2="27" style="stroke:#1e1e1eff;stroke-width:2;" /><line x1="21" y1="15" x2="21" y2="27" style="stroke:#202020ff;stroke-width:2;" /><line x1="22" y1="15" x2="22" y2="27" style="stroke:#222222ff;stroke-width:2;" /><line x1="23" y1="15" x2="23" y2="27" style="stroke:#232323ff;stroke-width:2;" /><line x1="24" y1="15" x2="24" y2="27" style="stroke:#252525ff;stroke-width:2;" /><line x1="25" y1="15" x2="25" y2="27" style="stroke:#262626ff;stroke-width:2;" /><line x1="26" y1="15" x2="26" y2="27" style="stroke:#282828ff;stroke-width:2;" /><line x1="27" y1="15" x2="27" y2="27" style="stroke:#292929ff;stroke-width:2;" /><line x1="28" y1="15" x2="28" y2="27" style="stroke:#2b2b2bff;stroke-width:2;" /><line x1="29" y1="15" x2="29" y2="27" style="stroke:#2c2c2cff;stroke-width:2;" /><line x1="30" y1="15" x2="30" y2="27" style="stroke:#2e2e2eff;stroke-width:2;" /><line x1="31" y1="15" x2="31" y2="27" style="stroke:#303030ff;stroke-width:2;" /><line x1="32" y1="15" x2="32" y2="27" style="stroke:#313131ff;stroke-width:2;" /><line x1="33" y1="15" x2="33" y2="27" style="stroke:#333333ff;stroke-width:2;" /><line x1="34" y1="15" x2="34" y2="27" style="stroke:#343434ff;stroke-width:2;" /><line x1="35" y1="15" x2="35" y2="27" style="stroke:#363636ff;stroke-width:2;" /><line x1="36" y1="15" x2="36" y2="27" style="stroke:#373737ff;stroke-width:2;" /><line x1="37" y1="15" x2="37" y2="27" style="stroke:#393939ff;stroke-width:2;" /><line x1="38" y1="15" x2="38" y2="27" style="stroke:#3a3a3aff;stroke-width:2;" /><line x1="39" y1="15" x2="39" y2="27" style="stroke:#3c3c3cff;stroke-width:2;" /><line x1="40" y1="15" x2="40" y2="27" style="stroke:#3d3d3dff;stroke-width:2;" /><line x1="41" y1="15" x2="41" y2="27" style="stroke:#3f3f3fff;stroke-width:2;" /><line x1="42" y1="15" x2="42" y2="27" style="stroke:#414141ff;stroke-width:2;" /><line x1="43" y1="15" x2="43" y2="27" style="stroke:#424242ff;stroke-width:2;" /><line x1="44" y1="15" x2="44" y2="27" style="stroke:#444444ff;stroke-width:2;" /><line x1="45" y1="15" x2="45" y2="27" style="stroke:#454545ff;stroke-width:2;" /><line x1="46" y1="15" x2="46" y2="27" style="stroke:#474747ff;stroke-width:2;" /><line x1="47" y1="15" x2="47" y2="27" style="stroke:#484848ff;stroke-width:2;" /><line x1="48" y1="15" x2="48" y2="27" style="stroke:#4a4a4aff;stroke-width:2;" /><line x1="49" y1="15"  ...

# %%
m = boreal_tiles[boreal_tiles.tile_num == TILE_NUM].boundary.explore(color='red', tiles=maplib_folium.tiler_basemap_image, attr=' ')
atl08_gdf.sample(frac=1).explore(m=m, column='h_can', cmap=pal_height_cmap,legend=True)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_3bca4bd55b53634fe501c5a81f36ea48 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/d3/3.5.5/d3.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_3bca4bd55b53634fe501c5a81f36ea48&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_3bca4bd55b53634fe501c5a81f36ea48 = L.map(
#                 &quot;map_3bca4bd55b53634fe501c5a81f36ea48&quot;,
#                 {
#                     center: [66.79869301666929, 179.04961777694342],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#             L.control.scale().addTo(map_3bca4bd55b53634fe501c5a81f36ea48);
#
#
#
#
#
#             var tile_layer_beacc46948d80834aba5df6c6b363f17 = L.tileLayer(
#                 &quot;https://services.arcgisonline.com/arcgis/rest/services/World_Imagery/MapServer/tile/{z}/{y}/{x}&quot;,
#                 {&quot;attribution&quot;: &quot; &quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_beacc46948d80834aba5df6c6b363f17.addTo(map_3bca4bd55b53634fe501c5a81f36ea48);
#
#
#             map_3bca4bd55b53634fe501c5a81f36ea48.fitBounds(
#                 [[66.39431431980967, 178.09924555388685], [67.2030717135289, 179.99999]],
#                 {}
#             );
#
#
#         function geo_json_e6b1250721c026391ce3d9f385053c92_styler(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;color&quot;: &quot;red&quot;, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#             }
#         }
#         function geo_json_e6b1250721c026391ce3d9f385053c92_highlighter(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;fillOpacity&quot;: 0.75};
#             }
#         }
#         function geo_json_e6b1250721c026391ce3d9f385053c92_pointToLayer(feature, latlng) {
#             var opts = {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 2, &quot;stroke&quot;: true, &quot;weight&quot;: 3};
#
#             let style = geo_json_e6b1250721c026391ce3d9f385053c92_styler(feature)
#             Object.assign(opts, style)
#
#             return new L.CircleMarker(latlng, opts)
#         }
#
#         function geo_json_e6b1250721c026391ce3d9f385053c92_onEachFeature(feature, layer) {
#             layer.on({
#                 mouseout: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                         geo_json_e6b1250721c026391ce3d9f385053c92.resetStyle(e.target);
#                     }
#                 },
#                 mouseover: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                         const highlightStyle = geo_json_e6b1250721c026391ce3d9f385053c92_highlighter(e.target.feature)
#                         e.target.setStyle(highlightStyle);
#                     }
#                 },
#             });
#         };
#         var geo_json_e6b1250721c026391ce3d9f385053c92 = L.geoJson(null, {
#                 onEachFeature: geo_json_e6b1250721c026391ce3d9f385053c92_onEachFeature,
#
#                 style: geo_json_e6b1250721c026391ce3d9f385053c92_styler,
#                 pointToLayer: geo_json_e6b1250721c026391ce3d9f385053c92_pointToLayer,
#         });
#
#         function geo_json_e6b1250721c026391ce3d9f385053c92_add (data) {
#             geo_json_e6b1250721c026391ce3d9f385053c92
#                 .addData(data);
#         }
#             geo_json_e6b1250721c026391ce3d9f385053c92_add({&quot;bbox&quot;: [178.09924555388685, 66.39431431980967, 179.99999, 67.2030717135289], &quot;features&quot;: [{&quot;bbox&qu

# %% [markdown]
# ##### [solved] ... problem: `tile_atl08` not finding the ATL08 granules for a given tile
# [solution]: needed to maap.searchGranule() using version 6

# %% [markdown]
# # Break down `tile_atl08` into its main steps

# %%
import ExtractUtils
import FilterUtils
import tile_atl08
# Out:
# NASA MAAP

# %% [markdown]
# ## Search: get the ATL08 30m h5 granules that intersect this tile
#  - PhoReal processed ATL08 v5 granules at 30m and stored as '.h5' files (DPS 1)
#  - We extracted dataframes (as CSVs) from each of these '.h5' granules

# %%
all_atl08_for_tile = ExtractUtils.maap_search_get_h5_list(tile_num=TILE_NUM, id_col=in_tile_id_col, tile_fn=in_tile_fn, layer=in_tile_layer, 
                                                          DATE_START='04-01', DATE_END='10-31', YEARS=[2019,2020,2021], 
                                                          version=6)
# Out:
# 	TILE_NUM: 168 (24.077368138647326,61.706101843775286,26.56167100903783,62.829301723925255)
# 	Searching MAAP for granules using these parameters:
# 	[{'short_name': 'ATL08', 'version': '006', 'bounding_box': '24.077368138647326,61.706101843775286,26.56167100903783,62.829301723925255', 'limit': 10000, 'temporal': '2019-04-01T00:00:00Z,2019-10-31T23:59:59Z'}, {'short_name': 'ATL08', 'version': '006', 'bounding_box': '24.077368138647326,61.706101843775286,26.56167100903783,62.829301723925255', 'limit': 10000, 'temporal': '2020-04-01T00:00:00Z,2020-10-31T23:59:59Z'}, {'short_name': 'ATL08', 'version': '006', 'bounding_box': '24.077368138647326,61.706101843775286,26.56167100903783,62.829301723925255', 'limit': 10000, 'temporal': '2021-04-01T00:00:00Z,2021-10-31T23:59:59Z'}]
# 		# ATL08 for tile 168: 308

# %%
print(f"\nReading existing list of ATL08 CSVs: {csv_list_fn}")
all_atl08_csvs_df = pd.read_csv(csv_list_fn)
# Get the s3 location from the location (local_path) indicated in the tindex master csv
all_atl08_csvs_df['s3'] = [tile_atl08.local_to_s3(local_path, 'lduncanson') for local_path in all_atl08_csvs_df['local_path']]
# Out:
# Reading existing list of ATL08 CSVs: /projects/shared-buckets/lduncanson/DPS_tile_lists/ATL08_tindex_master.csv

# %%
all_atl08_for_tile = [all_atl08_for_tile[i].replace('_006_','_005_') for i in range(len(all_atl08_for_tile))]

# %%
seg_str = '_30m'
all_atl08_csvs_FOUND, all_atl08_csvs_NOT_FOUND = FilterUtils.find_atl08_csv_tile(all_atl08_for_tile, all_atl08_csvs_df, seg_str, col_name='s3') 
print("\t# of ATL08 CSV found for tile {}: {}".format(TILE_NUM, len(all_atl08_csvs_FOUND)))
print("\t# of ATL08 CSV NOT found for tile {}: {}".format(TILE_NUM, len(all_atl08_csvs_NOT_FOUND)))
# Out:
# 	Find ATL08 CSVs you expect for a tile based on the h5 granule search...
# 		# of all ATL08 granules for tile: 308
# 		# of all_atl08_csvs: 46166
# 	# of ATL08 CSV found for tile 168: 114
# 	# of ATL08 CSV NOT found for tile 168: 194

# %% [markdown]
# ## Filter: spatial
# #### Get ATL08 gdf clipped to tile

# %%
# Get tile bounds as xmin,xmax,ymin,ymax
tile = ExtractUtils.get_index_tile(vector_path=in_tile_fn, id_col=in_tile_id_col, tile_id=TILE_NUM, buffer=0, layer=in_tile_layer)

# %%
import importlib
import FilterUtils
importlib.reload(FilterUtils)
# Out:
# <module 'FilterUtils' from '/projects/code/icesat2_boreal/lib/FilterUtils.py'>

# %%
import multiprocessing as mp
from multiprocessing import Pool
from functools import partial
mp.cpu_count()
# Out:
# 32

# %%
# Multprocessing this step does not work...
# %%time
# with Pool(processes=1) as pool:
#     atl08_list = pool.map(partial(FilterUtils.filter_atl08_bounds_clip, in_tile_geom_4326=tile['geom_4326']), all_atl08_csvs_FOUND[0:1])

# %%
atl08 = pd.concat([  FilterUtils.filter_atl08_bounds_clip(f, tile['geom_4326']) for f in all_atl08_csvs_FOUND ], sort=False, ignore_index=True)
# Out:
# Bounds clipped 34258 obs. down to 0 obs.
# Bounds clipped 34258 obs. down to 0 obs.
# Bounds clipped 42606 obs. down to 6770 obs.
# Bounds clipped 71832 obs. down to 1150 obs.
# Bounds clipped 54272 obs. down to 40 obs.
# Bounds clipped 146301 obs. down to 8286 obs.
# Bounds clipped 76916 obs. down to 109 obs.
# Bounds clipped 105311 obs. down to 6559 obs.
# Bounds clipped 96260 obs. down to 128 obs.
# Bounds clipped 54048 obs. down to 0 obs.
# Bounds clipped 123588 obs. down to 6860 obs.
# Bounds clipped 42512 obs. down to 0 obs.
# Bounds clipped 25249 obs. down to 24 obs.
# Bounds clipped 59329 obs. down to 6464 obs.
# Bounds clipped 111787 obs. down to 3557 obs.
# Bounds clipped 104162 obs. down to 9815 obs.
# Bounds clipped 65120 obs. down to 2735 obs.
# Bounds clipped 6484 obs. down to 62 obs.
# Bounds clipped 36593 obs. down to 1222 obs.
# Bounds clipped 48602 obs. down to 3753 obs.
# Bounds clipped 56402 obs. down to 856 obs.
# Bounds clipped 41075 obs. down to 10293 obs.
# Bounds clipped 60252 obs. down to 0 obs.
# Bounds clipped 108210 obs. down to 3153 obs.
# Bounds clipped 47779 obs. down to 52 obs.
# Bounds clipped 64240 obs. down to 226 obs.
# Bounds clipped 42608 obs. down to 3792 obs.
# Bounds clipped 92839 obs. down to 7486 obs.
# Bounds clipped 8880 obs. down to 323 obs.
# Bounds clipped 86065 obs. down to 274 obs.
# Bounds clipped 34399 obs. down to 2670 obs.
# Bounds clipped 41891 obs. down to 3071 obs.
# Bounds clipped 10352 obs. down to 8 obs.
# Bounds clipped 13909 obs. down to 0 obs.
# Bounds clipped 36002 obs. down to 50 obs.
# Bounds clipped 35856 obs. down to 0 obs.
# Bounds clipped 15988 obs. down to 0 obs.
# Bounds clipped 42606 obs. down to 6770 obs.
# Bounds clipped 71832 obs. down to 1150 obs.
# Bounds clipped 54272 obs. down to 40 obs.
# Bounds clipped 146301 obs. down to 8286 obs.
# Bounds clipped 76916 obs. down to 109 obs.
# Bounds clipped 105311 obs. down to 6559 obs.
# Bounds clipped 96260 obs. down to 128 obs.
# Bounds clipped 54048 obs. down to 0 obs.
# Bounds clipped 123588 obs. down to 6860 obs.
# Bounds clipped 42512 obs. down to 0 obs.
# Bounds clipped 25249 obs. down to 24 obs.
# Bounds clipped 59329 obs. down to 6464 obs.
# Bounds clipped 111787 obs. down to 3557 obs.
# Bounds clipped 104162 obs. down to 9815 obs.
# Bounds clipped 65120 obs. down to 2735 obs.
# Bounds clipped 6484 obs. down to 62 obs.
# Bounds clipped 36593 obs. down to 1222 obs.
# Bounds clipped 48602 obs. down to 3753 obs.
# Bounds clipped 56402 obs. down to 856 obs.
# Bounds clipped 41075 obs. down to 10293 obs.
# Bounds clipped 60252 obs. down to 0 obs.
# Bounds clipped 108210 obs. down to 3153 obs.
# Bounds clipped 47779 obs. down to 52 obs.
# Bounds clipped 64240 obs. down to 226 obs.
# Bounds clipped 42608 obs. down to 3792 obs.
# Bounds clipped 92839 obs. down to 7486 obs.
# Bounds clipped 8880 obs. down to 323 obs.
# Bounds clipped 86065 obs. down to 274 obs.
# Bounds clipped 34399 obs. down to 2670 obs.
# Bounds clipped 41891 obs. down to 3071 obs.
# Bounds clipped 10352 obs. down to 8 obs.
# Bounds clipped 13909 obs. down to 0 obs.
# Bounds clipped 36002 obs. down to 50 obs.
# Bounds clipped 35856 obs. down to 0 obs.
# Bounds clipped 15988 obs. down to 0 obs.
# Bounds clipped 86405 obs. down to 2572 obs.
# Bounds clipped 85336 obs. down to 40 obs.
# Bounds clipped 32558 obs. down to 0 obs.
# Bounds clipped 40419 obs. down to 5408 obs.
# Bounds clipped 31183 obs. down to 0 obs.
# Bounds clipped 23764 obs. down to 194 obs.
# Bounds clipped 40276 obs. down to 0 obs.
# Bounds clipped 26567 obs. down to 793 obs.
# Bounds clipped 117055 obs. down to 0 obs.
# Bounds clipped 109615 obs. down to 8789 obs.
# Bounds clipped 91532 obs. down to 5658 obs.
# Bounds clipped 42461 obs. down to 844 obs.
# Bounds clipped 109591 obs. down to 7811 obs.
# Bounds clipped 66320 obs. down to 9 obs.
# Bounds clipped 81998 obs. down to 3263 obs.
# Bounds clipped 129173 obs. down to 10699 obs.
# Bounds clipped 112213 obs. down to 3638 obs.
# Bounds clipped 64428 obs. down to 4242 obs.
# Bounds clipped 73780 obs. down to 8927 obs.
# Bounds clipped 49833 obs. down to 0 obs.
# Bounds clipped 98273 obs. down to 4979 obs.
# Bounds clipped 86405 obs. down to 2572 obs.
# Bounds clipped 85336 obs. down to 40 obs.
# Bounds clipped 32558 obs. down to 0 obs.
# Bounds clipped 40419 obs. down to 5408 obs.
# Bounds clipped 31183 obs. down to 0 obs.
# Bounds clipped 23764 obs. down to 194 obs.
# Bounds clipped 40276 obs. down to 0 obs.
# Bounds clipped 26567 obs. down to 793 obs.
# Bounds clipped 117055 obs. down to 0 obs.
# Bounds clipped 109615 obs. down to 8789 obs.
# Bounds clipped 91532 obs. down to 5658 obs.
# Bounds clipped 42461 obs. down to 844 obs.
# Bounds clipped 109591 obs. down to 7811 obs.
# Bounds clipped 66320 obs. down to 9 obs.
# Bounds clipped 81998 obs. down to 3263 obs.
# Bounds clipped 129173 obs. down to 10699 obs.
# Bounds clipped 112213 obs. down to 3638 obs.
# Bounds clipped 64428 obs. down to 4242 obs.
# Bounds clipped 73780 obs. down to 8927 obs.
# Bounds clipped 49833 obs. down to 0 obs.
# Bounds clipped 98273 obs. down to 4979 obs.

# %%
atl08.shape
# Out:
# (315308, 61)

# %% [markdown]
# ## Filter: quality
#
# Do the same thing we do in `tile_atl08`

# %%
atl08 = FilterUtils.prep_filter_atl08_qual(atl08)
# Out:
# Pre-filter data cleaning...
# Pandas version: 2.1.4
# 	Get beam type from orbit orientation and ground track: ['Weak' 'Strong']
# 	Cast some columns to:
# 		type float: ['lat', 'lon', 'h_can', 'h_te_best', 'ter_slp']
# 		type integer: ['n_ca_ph', 'n_seg_ph', 'n_toc_ph', 'msw_flg', 'seg_snow']

# %%
print('Quality filtering with aggressive land-cover based (v3) filters updated in Jan/Feb 2022 ...')
atl08_pdf_filt = FilterUtils.filter_atl08_qual_v3(atl08, SUBSET_COLS=True, DO_PREP=False,
                                                  subset_cols_list = ['rh25','rh50','rh60','rh70','rh75','rh80','rh90','h_can','h_max_can', 'ter_slp','h_te_best', 'seg_landcov','sol_el','y','m','doy'] + ['seg_cover'], #, 'granule_name'
                                           filt_cols=['h_can','h_dif_ref','m','msw_flg','beam_type','seg_snow','sig_topo'], 
                                           list_lc_h_can_thresh=[0, 60, 60, 60, 60, 60, 60, 50, 50, 50, 50, 50, 50, 20, 10, 10, 5, 5, 0, 0, 0, 0, 0],
                                           thresh_h_can=100, thresh_h_dif=25, thresh_sig_topo=2.5, month_min=MINMONTH, month_max=MAXMONTH)
# Out:
# Quality filtering with aggressive land-cover based (v3) filters updated in Jan/Feb 2022 ...
#
# Filtering by quality
# 	Before quality filtering: 		315308 observations in the input dataframe.
# 	After msw_flg=0: 		177894 observations in the dataframe.
# 	After beam_type=Strong: 		111840 observations in the dataframe.
# 	After seg_snow=1: 		110136 observations in the dataframe.
# 	Land cover threshold dictionary:
# {0: 0, 111: 60, 113: 60, 112: 60, 114: 60, 115: 60, 116: 60, 121: 50, 123: 50, 122: 50, 124: 50, 125: 50, 126: 50, 20: 20, 30: 10, 90: 10, 100: 5, 60: 5, 40: 0, 50: 0, 70: 0, 80: 0, 200: 0}
# 	After land-cover specific h_can thresholds: 		71634 observations in the dataframe.
# 	After h_can_unc <5, seg_cover<32767, sol_el<5, sig_topo<2.5, h_dif_ref<25: 		25488 observations in the dataframe.
# 	After month filters: 4-10
# 	After all quality filtering: 		25488 observations in the output dataframe.
# 	Returning a pandas data frame.
# 	Filtered obs. for columns: ['lon', 'lat', 'rh25', 'rh50', 'rh60', 'rh70', 'rh75', 'rh80', 'rh90', 'h_can', 'h_max_can', 'ter_slp', 'h_te_best', 'seg_landcov', 'sol_el', 'y', 'm', 'doy', 'seg_cover']
# 	Data frame shape: (25488, 19)

# %%
pct_obs_remaining = atl08_pdf_filt.shape[0] / atl08.shape[0] * 100 
print(f'Quality filtering reduced # valid obs by {round(100 - pct_obs_remaining, 1)}%')
# Out:
# Quality filtering reduced # valid obs by 91.9%

# %% [markdown]
# ## Test Covar Extraction to ATL08

# %%
import importlib
import ExtractUtils
importlib.reload(ExtractUtils)
# Out:
# NASA MAAP
# <module 'ExtractUtils' from '/projects/code/icesat2_boreal/lib/ExtractUtils.py'>

# %%
topo_covar_fn = tile_atl08.get_stack_fn(topo_stack_list_fn, TILE_NUM, user=None, col_name='local_path')
# Out:
# Getting stack fn from:  s3://maap-ops-workspace/shared/montesano/DPS_tile_lists/run_build_stack_topo/build_stack_v2023_2/CopernicusGLO30/Topo_tindex_master.csv
# 	 s3://maap-ops-workspace/montesano/dps_output/run_build_stack_topo/build_stack_v2023_2/CopernicusGLO30/2024/01/13/12/46/57/900208/CopernicusGLO30_168_cog_topo_stack.tif

# %%
atl08_extract_topo = ExtractUtils.extract_value_gdf_s3(topo_covar_fn, atl08.head(), None, reproject=True)
# Out:
# Getting stack fn from:  s3://maap-ops-workspace/shared/montesano/DPS_tile_lists/run_build_stack_topo/build_stack_v2023_2/CopernicusGLO30/Topo_tindex_master.csv
# 	 s3://maap-ops-workspace/montesano/dps_output/run_build_stack_topo/build_stack_v2023_2/CopernicusGLO30/2024/01/13/12/46/57/900208/CopernicusGLO30_168_cog_topo_stack.tif
# 	Extracting raster values from:  s3://maap-ops-workspace/montesano/dps_output/run_build_stack_topo/build_stack_v2023_2/CopernicusGLO30/2024/01/13/12/46/57/900208/CopernicusGLO30_168_cog_topo_stack.tif
# 	Re-project points to match raster...
# 	Geting bandnames list from raster descriptions...
# 	Returning 5 points with 5 new raster value columns: ['elevation', 'slope', 'tsri', 'tpi', 'slopemask']

# %%
sar_covar_fn = tile_atl08.get_stack_fn(sar_stack_list_fn, TILE_NUM, user='montesano', col_name='local_path')
atl08_extract_sar = ExtractUtils.extract_value_gdf_s3(sar_covar_fn, atl08.head(), None, reproject=True)
# Out:
# Getting stack fn from:  s3://maap-ops-workspace/shared/montesano/DPS_tile_lists/run_build_stack/build_stack_v2023_2/build_stack_S1/SAR_S1_2020/S1_tindex_master.csv
# 	 s3://maap-ops-workspace/montesano/dps_output/run_build_stack/build_stack_v2023_2/build_stack_S1/SAR_S1_2020/2024/01/18/10/54/18/776985/SAR_S1_2020_168_cog.tif
# 	Extracting raster values from:  s3://maap-ops-workspace/montesano/dps_output/run_build_stack/build_stack_v2023_2/build_stack_S1/SAR_S1_2020/2024/01/18/10/54/18/776985/SAR_S1_2020_168_cog.tif
# 	Re-project points to match raster...
# 	Geting bandnames list from raster descriptions...
# 	Returning 5 points with 9 new raster value columns: ['vv_median_frozen', 'vh_median_frozen', 'vv_median_summer', 'vh_median_summer', 'vv_median_shoulder', 'vh_median_shoulder', 'n_frozen', 'n_summer', 'n_shoulder']

# %%
hls_covar_fn = tile_atl08.get_stack_fn(landsat_stack_list_fn, TILE_NUM, user='montesano', col_name='local_path')
atl08_extract_hls = ExtractUtils.extract_value_gdf_s3(hls_covar_fn, atl08.head(), None, reproject=True)
# Out:
# Getting stack fn from:  s3://maap-ops-workspace/shared/montesano/DPS_tile_lists/HLS/HLS_stack_2023_v1/HLS_H30_2020/HLS_tindex_master.csv
# 	 s3://maap-ops-workspace/montesano/dps_output/do_HLS_stack_3-1-2/HLS_stack_2023_v1/HLS_H30_2020/2023/04/11/01/53/49/840528/HLS_168_07-01_08-31_2020_2020.tif
# 	Extracting raster values from:  s3://maap-ops-workspace/montesano/dps_output/do_HLS_stack_3-1-2/HLS_stack_2023_v1/HLS_H30_2020/2023/04/11/01/53/49/840528/HLS_168_07-01_08-31_2020_2020.tif
# 	Re-project points to match raster...
# 	Geting bandnames list from raster descriptions...
# 	Returning 5 points with 21 new raster value columns: ['Blue', 'Green', 'Red', 'NIR', 'SWIR', 'SWIR2', 'NDVI', 'SAVI', 'MSAVI', 'NDMI', 'EVI', 'NBR', 'NBR2', 'TCB', 'TCG', 'TCW', 'ValidMask', 'Xgeo', 'Ygeo', 'JulianDate', 'yearDate']

# %%
atl08_extract_hls
# Out:
#      fid        lon        lat                              dt  orb_orient  \
# 0  34917  25.759275  61.914410  b'2020-05-04T10:33:32.000000Z'           1
# 1  34918  25.759153  61.914944  b'2020-05-04T10:33:32.000000Z'           1
# 2  56569  25.808488  61.972040  b'2020-05-04T10:33:32.000000Z'           1
# 3  56570  25.808427  61.972308  b'2020-05-04T10:33:32.000000Z'           1
# 4  56571  25.807892  61.974715  b'2020-05-04T10:33:32.000000Z'           1
#
#    orb_num  rgt       gt      segid_beg      segid_end  ...       NBR  \
# 0     9117  594  b'gt2l'  344241.532366  344245.532366  ...  0.709852
# 1     9117  594  b'gt2l'  344244.513733  344248.513733  ...  0.664661
# 2     9117  594  b'gt3l'  344546.963859  344550.963859  ...  0.773686
# 3     9117  594  b'gt3l'  344548.461297  344552.461297  ...  0.764706
# 4     9117  594  b'gt3l'  344561.929031  344565.929031  ...  0.664865
#
#        NBR2       TCB       TCG       TCW  ValidMask       Xgeo       Ygeo  \
# 0  0.423206  0.202452  0.199669 -0.020284        1.0  8163439.0 -2546683.0
# 1  0.394203  0.173716  0.162022 -0.020495        1.0  8163499.0 -2546743.0
# 2  0.463066  0.201657  0.208552 -0.010437        1.0  8166649.0 -2552923.0
# 3  0.455108  0.201004  0.208075 -0.012182        1.0  8166679.0 -2552953.0
# 4  0.443946  0.037004  0.021257  0.000672        1.0  8166889.0 -2553103.0
#
#    JulianDate  yearDate
# 0       231.0    2020.0
# 1       231.0    2020.0
# 2       231.0    2020.0
# 3       231.0    2020.0
# 4       233.0    2020.0
#
# [5 rows x 77 columns]
